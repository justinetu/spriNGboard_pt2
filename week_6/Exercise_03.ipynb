# %% [markdown]
# # Exercise 03: Hyperparameter Tuning Part 3: Effects of Randomness
#
# **Make sure you have completed Exercise 01 and Exercise 02 before attempting this exercise!**
#
# In this exercise, you will explore the effects of randomness on hyperparameter tuning.

# %% [markdown]
# You know the drill:

# %%
import sys
# !{sys.executable} -m pip install -U pip
# !{sys.executable} -m pip install -U scikit-learn matplotlib
# Out:
# Requirement already satisfied: pip in /home/justin/.pyenv/versions/3.10.13/envs/sb_kev_wk6/lib/python3.10/site-packages (24.0)
# Requirement already satisfied: scikit-learn in /home/justin/.pyenv/versions/3.10.13/envs/sb_kev_wk6/lib/python3.10/site-packages (1.4.1.post1)
# Requirement already satisfied: matplotlib in /home/justin/.pyenv/versions/3.10.13/envs/sb_kev_wk6/lib/python3.10/site-packages (3.8.3)
# Requirement already satisfied: numpy<2.0,>=1.19.5 in /home/justin/.pyenv/versions/3.10.13/envs/sb_kev_wk6/lib/python3.10/site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /home/justin/.pyenv/versions/3.10.13/envs/sb_kev_wk6/lib/python3.10/site-packages (from scikit-learn) (1.12.0)
# Requirement already satisfied: joblib>=1.2.0 in /home/justin/.pyenv/versions/3.10.13/envs/sb_kev_wk6/lib/python3.10/site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/justin/.pyenv/versions/3.10.13/envs/sb_kev_wk6/lib/python3.10/site-packages (from scikit-learn) (3.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/justin/.pyenv/versions/3.10.13/envs/sb_kev_wk6/lib/python3.10/site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/justin/.pyenv/versions/3.10.13/envs/sb_kev_wk6/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/justin/.pyenv/versions/3.10.13/envs/sb_kev_wk6/lib/python3.10/site-packages (from matplotlib) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/justin/.pyenv/versions/3.10.13/envs/sb_kev_wk6/lib/python3.10/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /home/justin/.pyenv/versions/3.10.13/envs/sb_kev_wk6/lib/python3.10/site-packages (from matplotlib) (24.0)
# Requirement already satisfied: pillow>=8 in /home/justin/.pyenv/versions/3.10.13/envs/sb_kev_wk6/lib/python3.10/site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/justin/.pyenv/versions/3.10.13/envs/sb_kev_wk6/lib/python3.10/site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/justin/.pyenv/versions/3.10.13/envs/sb_kev_wk6/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/justin/.pyenv/versions/3.10.13/envs/sb_kev_wk6/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import matplotlib.pyplot as plt
import numpy as np

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split

# %% [markdown]
# We'll return to the underlying model from Exercise 01:

# %%
def true_fun(X):
    return np.cos(1.5 * np.pi * X)

# %% [markdown]
# The following code generates noisy samples of the model above.
#
# For each polynomial degree,
# it fits 20 models
# that are trained
# using different training/test data subsets.
#
# The results are then plotted below.

# %%
np.random.seed(3)

N_samples = 50
degrees = [1, 2, 3, 4, 5, 6, 10, 15, 20]

X_samples = np.sort(np.random.rand(N_samples))
y_samples = true_fun(X_samples) + np.random.randn(N_samples) * 0.1

N_cols = 3
N_rows = 1+(len(degrees)//N_cols)

plt.figure(figsize=(5*N_cols, 5*N_rows))
for i in range(len(degrees)):
    ax = plt.subplot(N_rows, N_cols, i + 1)
    plt.setp(ax, xticks=(), yticks=())

    xs = np.linspace(0, 1, 1000)
    plt.plot(xs, true_fun(xs), linewidth=5.0, color='m', label="True function")
    plt.scatter(X_samples, y_samples, edgecolor="b", s=20, label="Samples")

    pipeline = Pipeline([
        ("poly",   PolynomialFeatures(degree=degrees[i], include_bias=False)),
        ("linreg", LinearRegression()),
    ])

    for run_idx in range(20):
        X_train, X_test, y_train, y_test = train_test_split(X_samples, y_samples, test_size=0.5)
        pipeline.fit(X_train[:, np.newaxis], y_train)

        xs = np.linspace(0, 1, 1000)
        plt.plot(xs, pipeline.predict(xs[:, np.newaxis]))
        
    plt.xlabel("x")
    plt.ylabel("y")
    plt.xlim((0, 1))
    plt.ylim((-2, 2))
    plt.legend(loc="best")
    plt.title("Degree {}".format(degrees[i]))

plt.show()

# %% [markdown]
# **Which polynomial degree gives the most reliable results?  Justify your conclusion.**

# %% [markdown]
# Polynomial degree 4 gives the most reliable results because it follows the true function most accurately. It takes its general shape.

# %% [markdown]
# **Are there any polynomial degrees that you'd avoid?  Why?**

# %% [markdown]
# I would avoid 10, 15, 20 but moreso 15 and 20 because the models look far off from the true function. They're all over the place.

# %% [markdown]
# **What does changing the random seed do?  Why?  Would this be possible in practice?  How does it affect your preferred model?**

# %% [markdown]
# Changing the random seed changes the data which in turn changes the model. New data points are being generated. Higher degree polynomials are even more all over the place whereas, my preferred model doesn't change all that much.

# %% [markdown]
# (Make sure you reset the random seed to 3 before continuing.)

# %% [markdown]
# **What does increasing the noise standard deviation to 0.25 do?  Why?  Would this be possible in practice?  How does it affect your preferred model?**

# %% [markdown]
# Increasing the noise standard deviation to 0.25 spreads the noisy points more a part. This is essentially increases the spreed of the data. The model for the most part still best represents what the data is doing.

# %% [markdown]
# (Make sure you reset the standard deviation to 0.1 before continuing.)

# %% [markdown]
# **What does increasing the test fraction to 0.5 do?  Why?  Would this be possible in practice?  How does it affect your preferred model?**

# %% [markdown]
# Increasing the test fraction to 0.5 changes the models significantly. There's more variation in the models. If we remove too much data, there will not be enough data left to learn from in the sample data. The preferred model still takes the general shape of the true function however, here, polynomial degree 3 looks like a better fit.

# %% [markdown]
# (Make sure you reset the test fraction to 0.1.)

# %% [markdown]
# **Which degree has the highest bias?  Which has the highest variance?**

# %% [markdown]
# Degree 1 polynomial contains the most bias. Degree 15 or 20 has the highest variance because the model is complex.
